# %%
import ram.analysis.api as api

# %%
# Get all "runs"
import os
ddir = os.path.join(os.getenv('DATA'), 'ram', 'simulations', 'StatArbStrategy')
combos = api.get_combo_directories(ddir)

# %%
combos
# Out:
# ['Q:\\QUANT\\data\\ram\\simulations\\StatArbStrategy\\combo_0001',
#  'Q:\\QUANT\\data\\ram\\simulations\\StatArbStrategy\\combo_0002',
#  'Q:\\QUANT\\data\\ram\\simulations\\StatArbStrategy\\combo_0003',
#  'Q:\\QUANT\\data\\ram\\simulations\\StatArbStrategy\\combo_0004']

# %%
api.analyze_combo(combos[3])
# Out:
#                        0        1         2         3        4
# Total             2.4894   2.4848    2.4280    2.4280   2.4110
# Mean              0.0008   0.0008    0.0008    0.0008   0.0008
# Std               0.0031   0.0030    0.0031    0.0031   0.0030
# Skew              4.4811   4.0024    3.6396    4.5940   4.7261
# Kurt            112.5900  84.8300  107.5400  121.9900  96.8700
# Sharpe            4.1477   4.2195    4.0068    3.9580   4.0432
# Sortino           8.7617   9.0426    8.1519    8.2591   8.7975
# MinRet           -0.0448  -0.0405   -0.0501   -0.0465  -0.0372
# WinP              0.6733   0.6765    0.6730    0.6672   0.6630
# DD%              -0.0597  -0.0587   -0.0627   -0.0714  -0.0626
# DDDays           16.0000  17.0000   15.0000   18.0000   9.0000
# UnderwaterDays   53.0000  50.0000   52.0000   52.0000  52.0000
# Underwater%      -0.0120  -0.0127   -0.0125   -0.0127  -0.0136
# TimeAtHighs       0.4870   0.4820    0.4790    0.4750   0.4710
# VaR_5perc        -0.0021  -0.0021   -0.0022   -0.0021  -0.0021
# CVaR_5perc       -0.0046  -0.0045   -0.0046   -0.0046  -0.0046
# LPM_2             0.0023   0.0022    0.0025    0.0025   0.0022
