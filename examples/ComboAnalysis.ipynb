# %%
import ram.analysis.api as api

# %%
# Get all "runs"
import os
ddir = os.path.join(os.getenv('DATA'), 'ram', 'simulations', 'StatArbStrategy')
combos = api.get_combo_directories(ddir)

# %%
combos
# Out:
# ['Q:\\QUANT\\data\\ram\\simulations\\StatArbStrategy\\combo_0001']

# %%
api.analyze_combo(combos[0], start_year=2010)
# Out:
#                        0         1         2         3         4
# Total             0.2431    0.2114    0.2182    0.2056    0.2038
# Mean              0.0001    0.0001    0.0001    0.0001    0.0001
# Std               0.0015    0.0015    0.0015    0.0015    0.0016
# Skew              0.1007    0.0621    0.0971   -0.0578    0.0660
# Kurt              2.5600    2.2400    2.0600    1.9200    2.1700
# Sharpe            1.3998    1.2222    1.2720    1.1885    1.1682
# Sortino           2.4740    2.1360    2.2384    2.0463    2.0350
# MinRet           -0.0070   -0.0071   -0.0065   -0.0070   -0.0069
# WinP              0.5392    0.5359    0.5342    0.5387    0.5359
# DD%              -0.0304   -0.0365   -0.0308   -0.0325   -0.0323
# DDDays           56.0000  358.0000  115.0000   63.0000   60.0000
# UnderwaterDays  230.0000  358.0000  203.0000  276.0000  292.0000
# Underwater%      -0.0200   -0.0365   -0.0202   -0.0231   -0.0274
# ...

# %%
api.analyze_combo(combos[4], start_year=2010)
# Out:
#                        0         1         2         3         4
# Total             0.2521    0.2590    0.2528    0.2685    0.2494
# Mean              0.0001    0.0001    0.0001    0.0002    0.0001
# Std               0.0021    0.0021    0.0021    0.0021    0.0020
# Skew             -0.0822    0.0002    0.0123   -0.0342   -0.0100
# Kurt              3.4700    3.2300    3.8600    3.2400    3.1100
# Sharpe            1.0896    1.1235    1.0968    1.1608    1.0899
# Sortino           1.8445    1.9221    1.8791    1.9872    1.8628
# MinRet           -0.0107   -0.0102   -0.0118   -0.0114   -0.0102
# WinP              0.5364    0.5409    0.5314    0.5420    0.5359
# DD%              -0.0578   -0.0497   -0.0592   -0.0489   -0.0448
# DDDays          396.0000  276.0000  396.0000  219.0000  216.0000
# UnderwaterDays  396.0000  297.0000  396.0000  303.0000  315.0000
# Underwater%      -0.0578   -0.0277   -0.0592   -0.0316   -0.0308
# ...

# %%
api.analyze_combo(combos[4], start_year=2010)
# Out:
#                        0         1         2         3         4
# Total             0.2521    0.2590    0.2528    0.2685    0.2494
# Mean              0.0001    0.0001    0.0001    0.0002    0.0001
# Std               0.0021    0.0021    0.0021    0.0021    0.0020
# Skew             -0.0822    0.0002    0.0123   -0.0342   -0.0100
# Kurt              3.4700    3.2300    3.8600    3.2400    3.1100
# Sharpe            1.0896    1.1235    1.0968    1.1608    1.0899
# Sortino           1.8445    1.9221    1.8791    1.9872    1.8628
# MinRet           -0.0107   -0.0102   -0.0118   -0.0114   -0.0102
# WinP              0.5364    0.5409    0.5314    0.5420    0.5359
# DD%              -0.0578   -0.0497   -0.0592   -0.0489   -0.0448
# DDDays          396.0000  276.0000  396.0000  219.0000  216.0000
# UnderwaterDays  396.0000  297.0000  396.0000  303.0000  315.0000
# Underwater%      -0.0578   -0.0277   -0.0592   -0.0316   -0.0308
# ...
