# %%
import ram.analysis.api as api

# %%
# Get all "runs"
ddir = '/Users/mitchellsuter/Desktop/StatArbStrategy'
combos = api.get_combo_directories(ddir)

# %%
api.analyze_combo(combos[0])
# Out:
#                        0         1         2         3         4
# Total             0.2861    0.2913    0.2843    0.2754    0.2684
# Mean              0.0001    0.0001    0.0001    0.0001    0.0001
# Std               0.0012    0.0012    0.0011    0.0012    0.0012
# Skew              2.1584    2.2600    2.1845    2.6953    2.1738
# Kurt             31.9400   30.3400   27.3100   36.7000   31.7200
# Sharpe            1.2547    1.2844    1.2678    1.1893    1.1817
# Sortino           2.3450    2.4382    2.4095    2.2828    2.2055
# MinRet           -0.0111   -0.0102   -0.0082   -0.0090   -0.0106
# WinP              0.5414    0.5372    0.5349    0.5327    0.5369
# DD%              -0.0223   -0.0244   -0.0253   -0.0248   -0.0252
# DDDays          298.0000   20.0000   20.0000  429.0000  425.0000
# UnderwaterDays  298.0000  425.0000  301.0000  429.0000  425.0000
# Underwater%      -0.0223   -0.0234   -0.0202   -0.0248   -0.0252
# ...
